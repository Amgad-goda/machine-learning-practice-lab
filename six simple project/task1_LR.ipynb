# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.preprocessing import StandardScaler no need for that it was a mistake in ordering vars

# %% [markdown]
# # data

# %%
np.random.seed(42)
years_experience = np.random.uniform(0, 10, 50)
salary = 30000 + 5000 * years_experience + np.random.normal(0, 4000, 50)

df = pd.DataFrame({'YearsExperience': years_experience, 'Salary': salary})
# no need
# the data has inconsistent numbers of samples
# so import Standard Scale and scale the samples
print(df.head())
print(df.shape)
# Out:
#    YearsExperience        Salary
# 0         3.745401  51680.872262
# 1         9.507143  78221.188445
# 2         7.319939  66137.103961
# 3         5.986585  58728.509427
# 4         1.560186  31886.844061
# (50, 2)

# %% [markdown]
# # train & test

# %%
x = df[['YearsExperience']]
y = df['Salary']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)
print("x_train:", x_train.shape)
print("x_test:", x_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (40, 1)
# x_test: (10, 1)
# y_train: (40,)
# y_test: (10,)

# %%
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(x_test)

plt.scatter(x_train, y_train, color='blue', label='Train Data')
plt.scatter(x_test, y_test, color='red', label='Test Data')
plt.plot(x_test, y_pred, color='black', linewidth=2, label='Linear Regression')

plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Linear Regression Model')
plt.legend()
plt.show()

# %% [markdown]
# # mean & r^2

# %%
print('Slope (per year):', lr_model.coef_[0])
print('Intercept:', lr_model.intercept_)
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# Slope (per year): 4889.475725596843
# Intercept: 30494.684046308055
# R2 score: 0.9073954670069456
# MAE: 2735.3654910192868
